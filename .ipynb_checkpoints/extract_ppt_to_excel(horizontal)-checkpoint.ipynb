# %%
import glob
import os
from pptx import Presentation
import xlsxwriter
from pptx.enum.action import PP_ACTION
from pptx.enum.shapes import MSO_SHAPE_TYPE

n=1
image_filename=""
creative_id=""
e_row = 1   # 2번째 행부터 시작
e_col = 0

# 이미지 저장
def write_image(shape,creative_id):
    global n
    global image_filename
    image = shape.image
    image_bytes = image.blob
    image_filename = creative_id + '_' + fileName_only + '.jpg'
    n += 1
    print(image_filename)
    with open(image_filename, 'wb') as f:
        f.write(image_bytes)  
        
workbook = xlsxwriter.Workbook('hmotors_ad.xlsx')
worksheet = workbook.add_worksheet('data')
print('pptx를 옮겨쓰는 중이에요~')
    
for file in glob.glob("./*.pptx"):
    fileName_only = os.path.basename(file) #파일명
    filedir = os.path.abspath(file) #파일 경로
    
#     worksheet = workbook.add_worksheet(name = fileName_only) #파일명으로 시트 추가
    
    #엑셀 파일 1행 셋팅
    cell_format = workbook.add_format()
    cell_format.set_bg_color('#b7dee8')
    cell_format.set_bottom()
    worksheet.write(0,0,'Creative ID',cell_format)
    worksheet.write(0,1,'JPG 파일이 저장된 경로',cell_format)
    worksheet.write(0,2,'JPG 파일에 연결된 Link',cell_format)
    worksheet.write(0,3,'Title',cell_format)
    worksheet.write(0,4,'Media',cell_format)
    worksheet.write(0,5,'Description',cell_format)
    worksheet.write(0,6,'Country',cell_format)
    worksheet.write(0,7,'Product',cell_format)
    worksheet.write(0,8,'Category (Full Hierarchy):',cell_format)
    worksheet.write(0,9,'Date From',cell_format)
    worksheet.write(0,10,'Date To',cell_format)
    worksheet.write(0,11,'Channel',cell_format)
    worksheet.write(0,12,'First URL',cell_format)
    worksheet.write(0,13,'Publication',cell_format)
    worksheet.write(0,14,'Endline',cell_format)
    
    prs = Presentation(file)

    for slide in prs.slides:
        slide_num = prs.slides.index(slide)
        e_col = 0
        
        if(slide_num==0): #첫번째 슬라이드 제외
            continue
        for shape in slide.shapes:       
    
            #하이퍼링크 저장
            click_action = shape.click_action
            if click_action.action == PP_ACTION.HYPERLINK:
                worksheet.write(e_row,2,click_action.hyperlink.address)
            
            #테이블 내용 저장
            if shape.has_table:
                tbl = shape.table
                row_count = len(tbl.rows)
            
                for r in range(1, row_count):            #첫줄에 공백이 있음 & 첫 슬라의 prepared for 제거
                    if tbl.cell(r,0).text in "Title:":
                        worksheet.write(e_row,3,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Media:":  
                        worksheet.write(e_row,4,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Description:":  
                        worksheet.write(e_row,5,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Country:":  
                        worksheet.write(e_row,6,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Product:":  
                        worksheet.write(e_row,7,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Category (Full Hierarchy):":  
                        worksheet.write(e_row,8,tbl.cell(r,1).text)
    #                 elif tbl.cell(r,0).text == "Duration:":        
    #                     worksheet.write(e_row,e_col,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Date From/To:": 
                        if "-" in tbl.cell(r,1).text:
                            date_start = tbl.cell(r,1).text.split(' - ')[0]
                            date_end = tbl.cell(r,1).text.split(' - ')[1]
                            worksheet.write(e_row,9,date_start)
                            worksheet.write(e_row,10,date_end)
                        else:
                            worksheet.write(e_row,9,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Channel:":  
                        worksheet.write(e_row,11,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "First URL:":  
                        worksheet.write(e_row,12,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Publication:":  
                        worksheet.write(e_row,13,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Endline:":  
                        worksheet.write(e_row,14,tbl.cell(r,1).text)
                    elif tbl.cell(r,0).text in "Creative ID:":  
                        creative_id = tbl.cell(r,1).text
                        worksheet.write(e_row,0,creative_id)

            #이미지 저장
            if (creative_id != "") & (shape.shape_type == MSO_SHAPE_TYPE.PICTURE):
                write_image(shape,creative_id)
            
        #파일 경로 저장
        worksheet.write(e_row,1,filedir)                        
                    
        if(slide_num>0):                             #첫 슬라이드 제외
            e_row += 1

workbook.close()
# Out:
# pptx를 옮겨쓰는 중이에요~
# 1248913601_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248915301_HMB PRA Oct19-Apr20_.pptx.jpg
# 1249250301_HMB PRA Oct19-Apr20_.pptx.jpg
# 1249250301_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248913401_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248913401_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248910701_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248910701_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248902001_HMB PRA Oct19-Apr20_.pptx.jpg
# 1248902601_HMB PRA Oct19-Apr20_.pptx.jpg
# 1245708801_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1249890601_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1249884801_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1249883401_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1249879801_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1249880601_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1248221401_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1246498001_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1240412601_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1235916301_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1235149501_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1234587101_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233190301_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233029501_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233189801_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233028601_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233028101_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233028301_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1232472501_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1232473001_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1231255901_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1233187801_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1230367801_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1227621201_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1222440001_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1208555301_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1199534301_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1198674301_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1198627601_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1198476401_HMCIS DTA Oct 19-Apr20.pptx.jpg
# 1198467201_HMF TVC Oct19-Apr20.pptx.jpg
# 253246808_HMF TVC Oct19-Apr20.pptx.jpg
# 253207208_HMF TVC Oct19-Apr20.pptx.jpg
# 253022008_HMF TVC Oct19-Apr20.pptx.jpg
# 252940408_HMF TVC Oct19-Apr20.pptx.jpg
# 252854708_HMF TVC Oct19-Apr20.pptx.jpg
# 252333908_HMF TVC Oct19-Apr20.pptx.jpg
# 252050508_HMF TVC Oct19-Apr20.pptx.jpg
# 251526108_HMF TVC Oct19-Apr20.pptx.jpg
# 251462108_HMF TVC Oct19-Apr20.pptx.jpg
# 251812508_HMF TVC Oct19-Apr20.pptx.jpg
# 251896608_HMF TVC Oct19-Apr20.pptx.jpg
# 251586708_HMF TVC Oct19-Apr20.pptx.jpg
# 251425808_HMF TVC Oct19-Apr20.pptx.jpg
